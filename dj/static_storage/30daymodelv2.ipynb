# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
import numpy as np
import tqdm

# %%
Apath_to_df_ada="v2_lagging_A22apr_22may_2021_ada.hdf"
Apath_to_df_ada="v2_lagging_C28may_28may_2020_2021_ada.hdf"
Cpath_to_df_ada="v2_lagging_C28may_28may_2020_2021_ada.hdf"
Apath_to_df_ada = "v1_28may_28may_2020_2021_ada.hdf"

#Apath_to_df_eth="v2_lagging_A28may_28may_2020_2021_eth.hdf"


df = pd.read_hdf(Apath_to_df_ada)
df = df[:-180]
df
# Out:
#                                   trade_in_3h_usdtfutures_ADAUSDT_close_price  \
# 2020-06-09 05:00:59.999000+00:00                                     0.001993
# 2020-06-09 05:01:59.999000+00:00                                     0.001524
# 2020-06-09 05:02:59.999000+00:00                                     0.002111
# 2020-06-09 05:03:59.999000+00:00                                     0.002933
# 2020-06-09 05:04:59.999000+00:00                                     0.003759
# ...                                                                       ...
# 2021-06-10 07:32:59.999000+00:00                                     0.013018
# 2021-06-10 07:33:59.999000+00:00                                     0.015148
# 2021-06-10 07:34:59.999000+00:00                                     0.016623
# 2021-06-10 07:35:59.999000+00:00                                     0.013602
# 2021-06-10 07:36:59.999000+00:00                                     0.015520
#
#                                   trade_in_2h_usdtfutures_ADAUSDT_close_price  \
# 2020-06-09 05:00:59.999000+00:00                                    -0.000235
# 2020-06-09 05:01:59.999000+00:00                                    -0.000117
# 2020-06-09 05:02:59.999000+00:00                                    -0.000235
# 2020-06-09 05:03:59.999000+00:00                                     0.000704
# 2020-06-09 05:04:59.999000+00:00                                     0.001762
# ...                                                                       ...
# 2021-06-10 07:32:59.999000+00:00                                    -0.003318
# 2021-06-10 07:33:59.999000+00:00                                    -0.000511
# 2021-06-10 07:34:59.999000+00:00                                     0.002238
# 2021-06-10 07:35:59.999000+00:00                                     0.002746
# 2021-06-10 07:36:59.999000+00:00                                     0.002874
#
#                                   trade_in_1h_usdtfutures_ADAUSDT_close_price  \
# 2020-06-09 05:00:59.999000+00:00                                     0.002697
# 2020-06-09 05:01:59.999000+00:00                                     0.002462
# 2020-06-09 05:02:59.999000+00:00                                     0.002814
# 2020-06-09 05:03:59.999000+00:00                                     0.003050
# 2020-06-09 05:04:59.999000+00:00                                     0.003993
# ...                                                                       ...
# 2021-06-10 07:32:59.999000+00:00                                     0.001212
# 2021-06-10 07:33:59.999000+00:00                                     0.002684
# 2021-06-10 07:34:59.999000+00:00                                     0.002557
# 2021-06-10 07:35:59.999000+00:00                                    -0.000511
# 2021-06-10 07:36:59.999000+00:00                                    -0.000383
#
#                                   usdtfutures_ADAUSDT_close_price_ewm_mean  \
# 2020-06-09 05:00:59.999000+00:00                                  0.085313
# 2020-06-09 05:01:59.999000+00:00                                  0.085310
# 2020-06-09 05:02:59.999000+00:00                                  0.085308
# 2020-06-09 05:03:59.999000+00:00                                  0.085302
# 2020-06-09 05:04:59.999000+00:00                                  0.085287
# ...                                                                    ...
# 2021-06-10 07:32:59.999000+00:00                                  1.571137
# 2021-06-10 07:33:59.999000+00:00                                  1.570543
# 2021-06-10 07:34:59.999000+00:00                                  1.569957
# 2021-06-10 07:35:59.999000+00:00                                  1.569588
# 2021-06-10 07:36:59.999000+00:00                                  1.569235
#
#                                   usdtfutures_ADAUSDT_close_price_ewm_std  \
# 2020-06-09 05:00:59.999000+00:00                                 0.000023
# 2020-06-09 05:01:59.999000+00:00                                 0.000024
# 2020-06-09 05:02:59.999000+00:00                                 0.000024
# 2020-06-09 05:03:59.999000+00:00                                 0.000031
# 2020-06-09 05:04:59.999000+00:00                                 0.000056
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                                 0.003305
# 2021-06-10 07:33:59.999000+00:00                                 0.003693
# 2021-06-10 07:34:59.999000+00:00                                 0.004000
# 2021-06-10 07:35:59.999000+00:00                                 0.003997
# 2021-06-10 07:36:59.999000+00:00                                 0.003979
#
#                                   usdtfutures_ADAUSDT_close_price_ewm_cov  \
# 2020-06-09 05:00:59.999000+00:00                             5.150151e-10
# 2020-06-09 05:01:59.999000+00:00                             5.655684e-10
# 2020-06-09 05:02:59.999000+00:00                             5.946266e-10
# 2020-06-09 05:03:59.999000+00:00                             9.381074e-10
# 2020-06-09 05:04:59.999000+00:00                             3.117032e-09
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                             1.092509e-05
# 2021-06-10 07:33:59.999000+00:00                             1.363981e-05
# 2021-06-10 07:34:59.999000+00:00                             1.600158e-05
# 2021-06-10 07:35:59.999000+00:00                             1.597505e-05
# 2021-06-10 07:36:59.999000+00:00                             1.583455e-05
#
#                                   usdtfutures_ADAUSDT_close_price_mean_10  \
# 2020-06-09 05:00:59.999000+00:00                                 0.085314
# 2020-06-09 05:01:59.999000+00:00                                 0.085310
# 2020-06-09 05:02:59.999000+00:00                                 0.085307
# 2020-06-09 05:03:59.999000+00:00                                 0.085299
# 2020-06-09 05:04:59.999000+00:00                                 0.085281
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                                 1.570190
# 2021-06-10 07:33:59.999000+00:00                                 1.569380
# 2021-06-10 07:34:59.999000+00:00                                 1.568540
# 2021-06-10 07:35:59.999000+00:00                                 1.568090
# 2021-06-10 07:36:59.999000+00:00                                 1.567670
#
#                                   usdtfutures_ADAUSDT_close_price_skew_10  \
# 2020-06-09 05:00:59.999000+00:00                                -0.383399
# 2020-06-09 05:01:59.999000+00:00                                -0.083514
# 2020-06-09 05:02:59.999000+00:00                                 0.165209
# 2020-06-09 05:03:59.999000+00:00                                -0.228763
# 2020-06-09 05:04:59.999000+00:00                                -1.601920
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                                -0.327046
# 2021-06-10 07:33:59.999000+00:00                                -0.539819
# 2021-06-10 07:34:59.999000+00:00                                -0.388755
# 2021-06-10 07:35:59.999000+00:00                                 0.073848
# 2021-06-10 07:36:59.999000+00:00                                 0.514044
#
#                                   usdtfutures_ADAUSDT_close_price_kurt_10  \
# 2020-06-09 05:00:59.999000+00:00                               888.127261
# 2020-06-09 05:01:59.999000+00:00                             -1756.127144
# 2020-06-09 05:02:59.999000+00:00                               -96.127647
# 2020-06-09 05:03:59.999000+00:00                             -1651.311847
# 2020-06-09 05:04:59.999000+00:00                                42.636905
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                                -1.340194
# 2021-06-10 07:33:59.999000+00:00                                -0.406531
# 2021-06-10 07:34:59.999000+00:00                                -0.908664
# 2021-06-10 07:35:59.999000+00:00                                -1.151226
# 2021-06-10 07:36:59.999000+00:00                                -0.916914
#
#                                   usdtfutures_ADAUSDT_close_price_std_10  ...  \
# 2020-06-09 05:00:59.999000+00:00                                0.000021  ...
# 2020-06-09 05:01:59.999000+00:00                                0.000024  ...
# 2020-06-09 05:02:59.999000+00:00                                0.000025  ...
# 2020-06-09 05:03:59.999000+00:00                                0.000032  ...
# 2020-06-09 05:04:59.999000+00:00                                0.000059  ...
# ...                                                                  ...  ...
# 2021-06-10 07:32:59.999000+00:00                                0.002117  ...
# 2021-06-10 07:33:59.999000+00:00                                0.002555  ...
# 2021-06-10 07:34:59.999000+00:00                                0.002785  ...
# 2021-06-10 07:35:59.999000+00:00                                0.002815  ...
# 2021-06-10 07:36:59.999000+00:00                                0.002828  ...
#
#                                   usdtfutures_ADAUSDT_volume_mean_240  \
# 2020-06-09 05:00:59.999000+00:00                        186637.941667
# 2020-06-09 05:01:59.999000+00:00                        186407.783333
# 2020-06-09 05:02:59.999000+00:00                        185933.441667
# 2020-06-09 05:03:59.999000+00:00                        186248.312500
# 2020-06-09 05:04:59.999000+00:00                        185435.441667
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                        288153.862500
# 2021-06-10 07:33:59.999000+00:00                        288269.466667
# 2021-06-10 07:34:59.999000+00:00                        288925.658333
# 2021-06-10 07:35:59.999000+00:00                        289151.958333
# 2021-06-10 07:36:59.999000+00:00                        289545.333333
#
#                                   usdtfutures_ADAUSDT_volume_skew_240  \
# 2020-06-09 05:00:59.999000+00:00                             2.662934
# 2020-06-09 05:01:59.999000+00:00                             2.659648
# 2020-06-09 05:02:59.999000+00:00                             2.661552
# 2020-06-09 05:03:59.999000+00:00                             2.662064
# 2020-06-09 05:04:59.999000+00:00                             2.681518
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                             4.348526
# 2021-06-10 07:33:59.999000+00:00                             4.349054
# 2021-06-10 07:34:59.999000+00:00                             4.364321
# 2021-06-10 07:35:59.999000+00:00                             4.368246
# 2021-06-10 07:36:59.999000+00:00                             4.374041
#
#                                   usdtfutures_ADAUSDT_volume_kurt_240  \
# 2020-06-09 05:00:59.999000+00:00                             8.820239
# 2020-06-09 05:01:59.999000+00:00                             8.802305
# 2020-06-09 05:02:59.999000+00:00                             8.802333
# 2020-06-09 05:03:59.999000+00:00                             8.810897
# 2020-06-09 05:04:59.999000+00:00                             8.915167
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                            24.818173
# 2021-06-10 07:33:59.999000+00:00                            24.825221
# 2021-06-10 07:34:59.999000+00:00                            24.947887
# 2021-06-10 07:35:59.999000+00:00                            24.982069
# 2021-06-10 07:36:59.999000+00:00                            25.034243
#
#                                   usdtfutures_ADAUSDT_volume_std_240  \
# 2020-06-09 05:00:59.999000+00:00                       241571.273534
# 2020-06-09 05:01:59.999000+00:00                       241720.866289
# 2020-06-09 05:02:59.999000+00:00                       241830.132232
# 2020-06-09 05:03:59.999000+00:00                       241712.826171
# 2020-06-09 05:04:59.999000+00:00                       241358.621188
# ...                                                              ...
# 2021-06-10 07:32:59.999000+00:00                       258400.358479
# 2021-06-10 07:33:59.999000+00:00                       258365.548168
# 2021-06-10 07:34:59.999000+00:00                       257971.399525
# 2021-06-10 07:35:59.999000+00:00                       257855.666711
# 2021-06-10 07:36:59.999000+00:00                       257671.762042
#
#                                   usdtfutures_ADAUSDT_volume_cov_240  \
# 2020-06-09 05:00:59.999000+00:00                        5.835668e+10
# 2020-06-09 05:01:59.999000+00:00                        5.842898e+10
# 2020-06-09 05:02:59.999000+00:00                        5.848181e+10
# 2020-06-09 05:03:59.999000+00:00                        5.842509e+10
# 2020-06-09 05:04:59.999000+00:00                        5.825398e+10
# ...                                                              ...
# 2021-06-10 07:32:59.999000+00:00                        6.677075e+10
# 2021-06-10 07:33:59.999000+00:00                        6.675276e+10
# 2021-06-10 07:34:59.999000+00:00                        6.654924e+10
# 2021-06-10 07:35:59.999000+00:00                        6.648954e+10
# 2021-06-10 07:36:59.999000+00:00                        6.639474e+10
#
#                                   usdtfutures_ADAUSDT_volume_mean_480  \
# 2020-06-09 05:00:59.999000+00:00                                  NaN
# 2020-06-09 05:01:59.999000+00:00                                  NaN
# 2020-06-09 05:02:59.999000+00:00                                  NaN
# 2020-06-09 05:03:59.999000+00:00                                  NaN
# 2020-06-09 05:04:59.999000+00:00                                  NaN
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                        273036.839583
# 2021-06-10 07:33:59.999000+00:00                        273175.977083
# 2021-06-10 07:34:59.999000+00:00                        273265.575000
# 2021-06-10 07:35:59.999000+00:00                        273050.327083
# 2021-06-10 07:36:59.999000+00:00                        272914.037500
#
#                                   usdtfutures_ADAUSDT_volume_skew_480  \
# 2020-06-09 05:00:59.999000+00:00                                  NaN
# 2020-06-09 05:01:59.999000+00:00                                  NaN
# 2020-06-09 05:02:59.999000+00:00                                  NaN
# 2020-06-09 05:03:59.999000+00:00                                  NaN
# 2020-06-09 05:04:59.999000+00:00                                  NaN
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                             4.099572
# 2021-06-10 07:33:59.999000+00:00                             4.100633
# 2021-06-10 07:34:59.999000+00:00                             4.101309
# 2021-06-10 07:35:59.999000+00:00                             4.102175
# 2021-06-10 07:36:59.999000+00:00                             4.103174
#
#                                   usdtfutures_ADAUSDT_volume_kurt_480  \
# 2020-06-09 05:00:59.999000+00:00                                  NaN
# 2020-06-09 05:01:59.999000+00:00                                  NaN
# 2020-06-09 05:02:59.999000+00:00                                  NaN
# 2020-06-09 05:03:59.999000+00:00                                  NaN
# 2020-06-09 05:04:59.999000+00:00                                  NaN
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                            23.833654
# 2021-06-10 07:33:59.999000+00:00                            23.846568
# 2021-06-10 07:34:59.999000+00:00                            23.854884
# 2021-06-10 07:35:59.999000+00:00                            23.854410
# 2021-06-10 07:36:59.999000+00:00                            23.857652
#
#                                   usdtfutures_ADAUSDT_volume_std_480  \
# 2020-06-09 05:00:59.999000+00:00                                 NaN
# 2020-06-09 05:01:59.999000+00:00                                 NaN
# 2020-06-09 05:02:59.999000+00:00                                 NaN
# 2020-06-09 05:03:59.999000+00:00                                 NaN
# 2020-06-09 05:04:59.999000+00:00                                 NaN
# ...                                                              ...
# 2021-06-10 07:32:59.999000+00:00                       230942.139716
# 2021-06-10 07:33:59.999000+00:00                       230892.691859
# 2021-06-10 07:34:59.999000+00:00                       230860.877299
# 2021-06-10 07:35:59.999000+00:00                       230895.121643
# 2021-06-10 07:36:59.999000+00:00                       230909.153147
#
#                                   usdtfutures_ADAUSDT_volume_cov_480
# 2020-06-09 05:00:59.999000+00:00                                 NaN
# 2020-06-09 05:01:59.999000+00:00                                 NaN
# 2020-06-09 05:02:59.999000+00:00                                 NaN
# 2020-06-09 05:03:59.999000+00:00                                 NaN
# 2020-06-09 05:04:59.999000+00:00                                 NaN
# ...                                                              ...
# 2021-06-10 07:32:59.999000+00:00                        5.333427e+10
# 2021-06-10 07:33:59.999000+00:00                        5.331144e+10
# 2021-06-10 07:34:59.999000+00:00                        5.329674e+10
# 2021-06-10 07:35:59.999000+00:00                        5.331256e+10
# 2021-06-10 07:36:59.999000+00:00                        5.331904e+10
#
# [527197 rows x 49 columns]

# %%
df["daytime"]=df.index.hour/24
df
# Out:
#                                   trade_in_3h_usdtfutures_ADAUSDT_close_price  \
# 2020-06-09 05:00:59.999000+00:00                                     0.001993
# 2020-06-09 05:01:59.999000+00:00                                     0.001524
# 2020-06-09 05:02:59.999000+00:00                                     0.002111
# 2020-06-09 05:03:59.999000+00:00                                     0.002933
# 2020-06-09 05:04:59.999000+00:00                                     0.003759
# ...                                                                       ...
# 2021-06-10 07:32:59.999000+00:00                                     0.013018
# 2021-06-10 07:33:59.999000+00:00                                     0.015148
# 2021-06-10 07:34:59.999000+00:00                                     0.016623
# 2021-06-10 07:35:59.999000+00:00                                     0.013602
# 2021-06-10 07:36:59.999000+00:00                                     0.015520
#
#                                   trade_in_2h_usdtfutures_ADAUSDT_close_price  \
# 2020-06-09 05:00:59.999000+00:00                                    -0.000235
# 2020-06-09 05:01:59.999000+00:00                                    -0.000117
# 2020-06-09 05:02:59.999000+00:00                                    -0.000235
# 2020-06-09 05:03:59.999000+00:00                                     0.000704
# 2020-06-09 05:04:59.999000+00:00                                     0.001762
# ...                                                                       ...
# 2021-06-10 07:32:59.999000+00:00                                    -0.003318
# 2021-06-10 07:33:59.999000+00:00                                    -0.000511
# 2021-06-10 07:34:59.999000+00:00                                     0.002238
# 2021-06-10 07:35:59.999000+00:00                                     0.002746
# 2021-06-10 07:36:59.999000+00:00                                     0.002874
#
#                                   trade_in_1h_usdtfutures_ADAUSDT_close_price  \
# 2020-06-09 05:00:59.999000+00:00                                     0.002697
# 2020-06-09 05:01:59.999000+00:00                                     0.002462
# 2020-06-09 05:02:59.999000+00:00                                     0.002814
# 2020-06-09 05:03:59.999000+00:00                                     0.003050
# 2020-06-09 05:04:59.999000+00:00                                     0.003993
# ...                                                                       ...
# 2021-06-10 07:32:59.999000+00:00                                     0.001212
# 2021-06-10 07:33:59.999000+00:00                                     0.002684
# 2021-06-10 07:34:59.999000+00:00                                     0.002557
# 2021-06-10 07:35:59.999000+00:00                                    -0.000511
# 2021-06-10 07:36:59.999000+00:00                                    -0.000383
#
#                                   usdtfutures_ADAUSDT_close_price_ewm_mean  \
# 2020-06-09 05:00:59.999000+00:00                                  0.085313
# 2020-06-09 05:01:59.999000+00:00                                  0.085310
# 2020-06-09 05:02:59.999000+00:00                                  0.085308
# 2020-06-09 05:03:59.999000+00:00                                  0.085302
# 2020-06-09 05:04:59.999000+00:00                                  0.085287
# ...                                                                    ...
# 2021-06-10 07:32:59.999000+00:00                                  1.571137
# 2021-06-10 07:33:59.999000+00:00                                  1.570543
# 2021-06-10 07:34:59.999000+00:00                                  1.569957
# 2021-06-10 07:35:59.999000+00:00                                  1.569588
# 2021-06-10 07:36:59.999000+00:00                                  1.569235
#
#                                   usdtfutures_ADAUSDT_close_price_ewm_std  \
# 2020-06-09 05:00:59.999000+00:00                                 0.000023
# 2020-06-09 05:01:59.999000+00:00                                 0.000024
# 2020-06-09 05:02:59.999000+00:00                                 0.000024
# 2020-06-09 05:03:59.999000+00:00                                 0.000031
# 2020-06-09 05:04:59.999000+00:00                                 0.000056
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                                 0.003305
# 2021-06-10 07:33:59.999000+00:00                                 0.003693
# 2021-06-10 07:34:59.999000+00:00                                 0.004000
# 2021-06-10 07:35:59.999000+00:00                                 0.003997
# 2021-06-10 07:36:59.999000+00:00                                 0.003979
#
#                                   usdtfutures_ADAUSDT_close_price_ewm_cov  \
# 2020-06-09 05:00:59.999000+00:00                             5.150151e-10
# 2020-06-09 05:01:59.999000+00:00                             5.655684e-10
# 2020-06-09 05:02:59.999000+00:00                             5.946266e-10
# 2020-06-09 05:03:59.999000+00:00                             9.381074e-10
# 2020-06-09 05:04:59.999000+00:00                             3.117032e-09
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                             1.092509e-05
# 2021-06-10 07:33:59.999000+00:00                             1.363981e-05
# 2021-06-10 07:34:59.999000+00:00                             1.600158e-05
# 2021-06-10 07:35:59.999000+00:00                             1.597505e-05
# 2021-06-10 07:36:59.999000+00:00                             1.583455e-05
#
#                                   usdtfutures_ADAUSDT_close_price_mean_10  \
# 2020-06-09 05:00:59.999000+00:00                                 0.085314
# 2020-06-09 05:01:59.999000+00:00                                 0.085310
# 2020-06-09 05:02:59.999000+00:00                                 0.085307
# 2020-06-09 05:03:59.999000+00:00                                 0.085299
# 2020-06-09 05:04:59.999000+00:00                                 0.085281
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                                 1.570190
# 2021-06-10 07:33:59.999000+00:00                                 1.569380
# 2021-06-10 07:34:59.999000+00:00                                 1.568540
# 2021-06-10 07:35:59.999000+00:00                                 1.568090
# 2021-06-10 07:36:59.999000+00:00                                 1.567670
#
#                                   usdtfutures_ADAUSDT_close_price_skew_10  \
# 2020-06-09 05:00:59.999000+00:00                                -0.383399
# 2020-06-09 05:01:59.999000+00:00                                -0.083514
# 2020-06-09 05:02:59.999000+00:00                                 0.165209
# 2020-06-09 05:03:59.999000+00:00                                -0.228763
# 2020-06-09 05:04:59.999000+00:00                                -1.601920
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                                -0.327046
# 2021-06-10 07:33:59.999000+00:00                                -0.539819
# 2021-06-10 07:34:59.999000+00:00                                -0.388755
# 2021-06-10 07:35:59.999000+00:00                                 0.073848
# 2021-06-10 07:36:59.999000+00:00                                 0.514044
#
#                                   usdtfutures_ADAUSDT_close_price_kurt_10  \
# 2020-06-09 05:00:59.999000+00:00                               888.127261
# 2020-06-09 05:01:59.999000+00:00                             -1756.127144
# 2020-06-09 05:02:59.999000+00:00                               -96.127647
# 2020-06-09 05:03:59.999000+00:00                             -1651.311847
# 2020-06-09 05:04:59.999000+00:00                                42.636905
# ...                                                                   ...
# 2021-06-10 07:32:59.999000+00:00                                -1.340194
# 2021-06-10 07:33:59.999000+00:00                                -0.406531
# 2021-06-10 07:34:59.999000+00:00                                -0.908664
# 2021-06-10 07:35:59.999000+00:00                                -1.151226
# 2021-06-10 07:36:59.999000+00:00                                -0.916914
#
#                                   usdtfutures_ADAUSDT_close_price_std_10  ...  \
# 2020-06-09 05:00:59.999000+00:00                                0.000021  ...
# 2020-06-09 05:01:59.999000+00:00                                0.000024  ...
# 2020-06-09 05:02:59.999000+00:00                                0.000025  ...
# 2020-06-09 05:03:59.999000+00:00                                0.000032  ...
# 2020-06-09 05:04:59.999000+00:00                                0.000059  ...
# ...                                                                  ...  ...
# 2021-06-10 07:32:59.999000+00:00                                0.002117  ...
# 2021-06-10 07:33:59.999000+00:00                                0.002555  ...
# 2021-06-10 07:34:59.999000+00:00                                0.002785  ...
# 2021-06-10 07:35:59.999000+00:00                                0.002815  ...
# 2021-06-10 07:36:59.999000+00:00                                0.002828  ...
#
#                                   usdtfutures_ADAUSDT_volume_skew_240  \
# 2020-06-09 05:00:59.999000+00:00                             2.662934
# 2020-06-09 05:01:59.999000+00:00                             2.659648
# 2020-06-09 05:02:59.999000+00:00                             2.661552
# 2020-06-09 05:03:59.999000+00:00                             2.662064
# 2020-06-09 05:04:59.999000+00:00                             2.681518
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                             4.348526
# 2021-06-10 07:33:59.999000+00:00                             4.349054
# 2021-06-10 07:34:59.999000+00:00                             4.364321
# 2021-06-10 07:35:59.999000+00:00                             4.368246
# 2021-06-10 07:36:59.999000+00:00                             4.374041
#
#                                   usdtfutures_ADAUSDT_volume_kurt_240  \
# 2020-06-09 05:00:59.999000+00:00                             8.820239
# 2020-06-09 05:01:59.999000+00:00                             8.802305
# 2020-06-09 05:02:59.999000+00:00                             8.802333
# 2020-06-09 05:03:59.999000+00:00                             8.810897
# 2020-06-09 05:04:59.999000+00:00                             8.915167
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                            24.818173
# 2021-06-10 07:33:59.999000+00:00                            24.825221
# 2021-06-10 07:34:59.999000+00:00                            24.947887
# 2021-06-10 07:35:59.999000+00:00                            24.982069
# 2021-06-10 07:36:59.999000+00:00                            25.034243
#
#                                   usdtfutures_ADAUSDT_volume_std_240  \
# 2020-06-09 05:00:59.999000+00:00                       241571.273534
# 2020-06-09 05:01:59.999000+00:00                       241720.866289
# 2020-06-09 05:02:59.999000+00:00                       241830.132232
# 2020-06-09 05:03:59.999000+00:00                       241712.826171
# 2020-06-09 05:04:59.999000+00:00                       241358.621188
# ...                                                              ...
# 2021-06-10 07:32:59.999000+00:00                       258400.358479
# 2021-06-10 07:33:59.999000+00:00                       258365.548168
# 2021-06-10 07:34:59.999000+00:00                       257971.399525
# 2021-06-10 07:35:59.999000+00:00                       257855.666711
# 2021-06-10 07:36:59.999000+00:00                       257671.762042
#
#                                   usdtfutures_ADAUSDT_volume_cov_240  \
# 2020-06-09 05:00:59.999000+00:00                        5.835668e+10
# 2020-06-09 05:01:59.999000+00:00                        5.842898e+10
# 2020-06-09 05:02:59.999000+00:00                        5.848181e+10
# 2020-06-09 05:03:59.999000+00:00                        5.842509e+10
# 2020-06-09 05:04:59.999000+00:00                        5.825398e+10
# ...                                                              ...
# 2021-06-10 07:32:59.999000+00:00                        6.677075e+10
# 2021-06-10 07:33:59.999000+00:00                        6.675276e+10
# 2021-06-10 07:34:59.999000+00:00                        6.654924e+10
# 2021-06-10 07:35:59.999000+00:00                        6.648954e+10
# 2021-06-10 07:36:59.999000+00:00                        6.639474e+10
#
#                                   usdtfutures_ADAUSDT_volume_mean_480  \
# 2020-06-09 05:00:59.999000+00:00                                  NaN
# 2020-06-09 05:01:59.999000+00:00                                  NaN
# 2020-06-09 05:02:59.999000+00:00                                  NaN
# 2020-06-09 05:03:59.999000+00:00                                  NaN
# 2020-06-09 05:04:59.999000+00:00                                  NaN
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                        273036.839583
# 2021-06-10 07:33:59.999000+00:00                        273175.977083
# 2021-06-10 07:34:59.999000+00:00                        273265.575000
# 2021-06-10 07:35:59.999000+00:00                        273050.327083
# 2021-06-10 07:36:59.999000+00:00                        272914.037500
#
#                                   usdtfutures_ADAUSDT_volume_skew_480  \
# 2020-06-09 05:00:59.999000+00:00                                  NaN
# 2020-06-09 05:01:59.999000+00:00                                  NaN
# 2020-06-09 05:02:59.999000+00:00                                  NaN
# 2020-06-09 05:03:59.999000+00:00                                  NaN
# 2020-06-09 05:04:59.999000+00:00                                  NaN
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                             4.099572
# 2021-06-10 07:33:59.999000+00:00                             4.100633
# 2021-06-10 07:34:59.999000+00:00                             4.101309
# 2021-06-10 07:35:59.999000+00:00                             4.102175
# 2021-06-10 07:36:59.999000+00:00                             4.103174
#
#                                   usdtfutures_ADAUSDT_volume_kurt_480  \
# 2020-06-09 05:00:59.999000+00:00                                  NaN
# 2020-06-09 05:01:59.999000+00:00                                  NaN
# 2020-06-09 05:02:59.999000+00:00                                  NaN
# 2020-06-09 05:03:59.999000+00:00                                  NaN
# 2020-06-09 05:04:59.999000+00:00                                  NaN
# ...                                                               ...
# 2021-06-10 07:32:59.999000+00:00                            23.833654
# 2021-06-10 07:33:59.999000+00:00                            23.846568
# 2021-06-10 07:34:59.999000+00:00                            23.854884
# 2021-06-10 07:35:59.999000+00:00                            23.854410
# 2021-06-10 07:36:59.999000+00:00                            23.857652
#
#                                   usdtfutures_ADAUSDT_volume_std_480  \
# 2020-06-09 05:00:59.999000+00:00                                 NaN
# 2020-06-09 05:01:59.999000+00:00                                 NaN
# 2020-06-09 05:02:59.999000+00:00                                 NaN
# 2020-06-09 05:03:59.999000+00:00                                 NaN
# 2020-06-09 05:04:59.999000+00:00                                 NaN
# ...                                                              ...
# 2021-06-10 07:32:59.999000+00:00                       230942.139716
# 2021-06-10 07:33:59.999000+00:00                       230892.691859
# 2021-06-10 07:34:59.999000+00:00                       230860.877299
# 2021-06-10 07:35:59.999000+00:00                       230895.121643
# 2021-06-10 07:36:59.999000+00:00                       230909.153147
#
#                                   usdtfutures_ADAUSDT_volume_cov_480   daytime
# 2020-06-09 05:00:59.999000+00:00                                 NaN  0.208333
# 2020-06-09 05:01:59.999000+00:00                                 NaN  0.208333
# 2020-06-09 05:02:59.999000+00:00                                 NaN  0.208333
# 2020-06-09 05:03:59.999000+00:00                                 NaN  0.208333
# 2020-06-09 05:04:59.999000+00:00                                 NaN  0.208333
# ...                                                              ...       ...
# 2021-06-10 07:32:59.999000+00:00                        5.333427e+10  0.291667
# 2021-06-10 07:33:59.999000+00:00                        5.331144e+10  0.291667
# 2021-06-10 07:34:59.999000+00:00                        5.329674e+10  0.291667
# 2021-06-10 07:35:59.999000+00:00                        5.331256e+10  0.291667
# 2021-06-10 07:36:59.999000+00:00                        5.331904e+10  0.291667
#
# [527197 rows x 50 columns]

# %%
def check_x_for_leak(X):
    for column in X.columns:
        assert "trade_in_" not in column

# %%
def create_model(df_orig, index, train_size, test_size, coin):
    df_orig = df_orig.fillna(0)
    del df_orig["trade_in_3h_usdtfutures_{}USDT_close_price".format(coin)]
    del df_orig["trade_in_2h_usdtfutures_{}USDT_close_price".format(coin)]
    start = index - (train_size+test_size)
    end = index
    df_orig = df_orig[start:end]

    df = df_orig.copy()
    df = df.sample(frac=1/8)
    Y = df["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)]

    Y_MEAN = np.mean(np.abs(Y))
    Y_MEAN = Y_MEAN * (1/8)

    Y[df["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)] > Y_MEAN] = 20
    Y[df["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)] < -Y_MEAN] = 10
    Y[df["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)] < 9] = 1

    first_element = "usdtfutures_{}USDT_close_price".format(coin)
    #first_element = "usdtfutures_{}USDT_close_price_ewm_mean".format(coin)
    
    X = df.loc[:, first_element :]
    check_x_for_leak(X)

    test_size = test_size / (test_size+train_size)
    test_size = test_size or 0.01
    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=test_size, random_state=6, shuffle=False
    )
    hours_in_test = len(Y_test)

    model = XGBClassifier(
        objective="multi:softprob",
        num_class=3,
        #booster=["gbtree","gblinear"][0],
        gamma=0.1,
        #sampling_method=["uniform", "gradient_based"][1],
        #num_parallel_tree=1,
        #reg_alpha=1,
        #reg_lambda=0,
        #eta=0.3,
    )
    model.fit(X_train, Y_train)
    return model

# %%
def predict_row(df_orig, index, model, coin):
    #del df_orig["trade_in_3h_usdtfutures_{}USDT_close_price".format(coin)]
    #del df_orig["trade_in_2h_usdtfutures_{}USDT_close_price".format(coin)]
    df_orig = df_orig.iloc[index:index+1]
    df_orig = df_orig.copy()
    df_orig = df_orig.fillna(0)
    
    first_element = "usdtfutures_{}USDT_close_price".format(coin)
    #first_element = "usdtfutures_{}USDT_close_price_ewm_mean".format(coin)
    X = df_orig.loc[:,first_element :]
    check_x_for_leak(X)
    y_pred = model.predict(X)[0]
    Y_TEST_REAL = df_orig["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)][0]
    
    profit = -1
    
    side = -1
    if y_pred == 20:
        side = 1
    if y_pred == 1:
        return Y_TEST_REAL, 0

    if side * Y_TEST_REAL > 0:
        profit = 1
    
    return abs(Y_TEST_REAL) * profit, side

# %%
predictsA = []
predictsB = []
predictsC = []
model_A = None
model_B = None
model_C = None
last_model_train_A = 0
last_model_train_B = 0
last_model_train_C = 0
retrain_limit_A = 60*24*2
retrain_limit_B = 60*24*2
retrain_limit_C = 60*24*2
df_orig_A = pd.read_hdf("v3_lagging_A28may_28may_2020_2021_ada.hdf")
df_orig_B = pd.read_hdf("v3_lagging_A28may_28may_2020_2021_ada.hdf")
df_orig_C = pd.read_hdf("v3_lagging_A28may_28may_2020_2021_ada.hdf")
for i in tqdm.tqdm(range(60*24*270, 60*24*360, 120)):

    if (i - last_model_train_A) > retrain_limit_A:
        model_A = None
    if (i - last_model_train_B) > retrain_limit_B:
        model_B = None
    if (i - last_model_train_C) > retrain_limit_C:
        model_C = None

    

    if model_A is None:
        #model_A = create_model(df_orig_A.copy(), i-61, (60*24*20), 0, "ADA")
        last_model_train_A = i
    #predictA = predict_row(df_orig_A, i, model_A, "ADA")

    
    if model_B is None:
        #model_B = create_model(df_orig_B.copy(), i-61, (60*24*30), 0, "ADA")
        last_model_train_B = i
    #predictB = predict_row(df_orig_B, i, model_B, "ADA")



    if model_C is None:
        model_C = create_model(df_orig_C.copy(), i-61, (60*24*60), 0, "ADA")
        last_model_train_C = i
    predictC = predict_row(df_orig_C, i, model_C, "ADA")
    
    

    predictsA.append(predictC)
    predictsB.append(predictC)
    predictsC.append(predictC)
# Out:
#   0%|          | 0/1080 [00:00<?, ?it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:07:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   2%|▏         | 25/1080 [00:12<06:07,  2.87it/s] /home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:07:24] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   4%|▍         | 46/1080 [00:19<05:48,  2.97it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:07:31] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   5%|▌         | 55/1080 [00:25<07:18,  2.34it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:07:37] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   7%|▋         | 76/1080 [00:29<05:33,  3.01it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:07:42] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#   9%|▉         | 101/1080 [00:34<04:14,  3.85it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:07:46] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  12%|█▏        | 126/1080 [00:38<03:37,  4.39it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:07:50] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  14%|█▍        | 151/1080 [00:42<03:13,  4.80it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:07:55] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  16%|█▋        | 176/1080 [00:47<03:01,  4.98it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:07:59] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  19%|█▊        | 201/1080 [00:52<02:50,  5.14it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:04] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  21%|██        | 226/1080 [00:56<02:40,  5.33it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:08] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  23%|██▎       | 251/1080 [01:00<02:29,  5.54it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  26%|██▌       | 276/1080 [01:04<02:22,  5.66it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:16] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  28%|██▊       | 301/1080 [01:09<02:19,  5.60it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:21] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  30%|███       | 326/1080 [01:13<02:14,  5.61it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:26] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  32%|███▎      | 351/1080 [01:18<02:09,  5.61it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:30] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  35%|███▍      | 376/1080 [01:22<02:05,  5.62it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:34] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  37%|███▋      | 401/1080 [01:27<02:04,  5.43it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  39%|███▉      | 426/1080 [01:32<02:02,  5.33it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:44] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  42%|████▏     | 451/1080 [01:38<02:10,  4.82it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:51] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  45%|████▍     | 483/1080 [01:44<01:54,  5.23it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:08:57] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  46%|████▋     | 501/1080 [01:52<02:36,  3.70it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:05] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  49%|████▊     | 526/1080 [01:57<02:15,  4.08it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:10] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  51%|█████     | 551/1080 [02:04<02:09,  4.09it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:16] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  53%|█████▎    | 576/1080 [02:10<02:02,  4.12it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:22] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  56%|█████▌    | 601/1080 [02:14<01:48,  4.40it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:27] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  58%|█████▊    | 626/1080 [02:19<01:38,  4.62it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:32] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  62%|██████▏   | 673/1080 [02:24<01:01,  6.67it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:36] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  63%|██████▎   | 680/1080 [02:28<01:22,  4.87it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:41] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  65%|██████▍   | 701/1080 [02:33<01:19,  4.74it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:45] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  67%|██████▋   | 726/1080 [02:38<01:11,  4.96it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:50] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  70%|██████▉   | 751/1080 [02:42<01:03,  5.18it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:09:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  72%|███████▏  | 776/1080 [02:48<01:03,  4.82it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:00] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  74%|███████▍  | 801/1080 [02:53<00:57,  4.83it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:05] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  78%|███████▊  | 842/1080 [03:00<00:41,  5.73it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  79%|███████▉  | 851/1080 [03:06<00:57,  3.97it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:18] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  81%|████████  | 876/1080 [03:11<00:48,  4.20it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:24] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  83%|████████▎ | 901/1080 [03:16<00:39,  4.49it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:28] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  86%|████████▌ | 926/1080 [03:21<00:32,  4.81it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:33] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  88%|████████▊ | 951/1080 [03:26<00:26,  4.86it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  90%|█████████ | 976/1080 [03:30<00:20,  5.00it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:43] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  93%|█████████▎| 1001/1080 [03:35<00:15,  5.14it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:47] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  95%|█████████▌| 1026/1080 [03:43<00:12,  4.33it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:10:55] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#  97%|█████████▋| 1051/1080 [03:48<00:06,  4.53it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:11:00] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 100%|██████████| 1080/1080 [03:53<00:00,  4.63it/s]

# %%
initial_bank = 100
rake = 0.00018

last_side = -1
last_coin = "ADA"
coin="ADA"
for i in range(len(predictsA)):
    if i ==0:
        continue

    predicts = predictsA
    
    win_len = 50
    A_sum = predictsA[i-win_len:i-1]
    B_sum = predictsB[i-win_len:i-1]
    C_sum = predictsC[i-win_len:i-1]
    A_sum  = sum([x[0] for x in A_sum if x[1] !=0])
    B_sum  = sum([x[0] for x in B_sum if x[1] !=0])
    C_sum  = sum([x[0] for x in C_sum if x[1] !=0])
    
    
    predicts= predictsA
    if A_sum < B_sum:
        predicts = predictsB
        if B_sum < C_sum:
            predicts = predictsC
    predicts= predictsC

    
    p, side = predicts[i]
    if side ==0:
        profit = -1
        if p * last_side > 0:
            profit = 1
        p = abs(p)*profit
        side = last_side


    change = initial_bank * p
    initial_bank = initial_bank + change
    
    if side != last_side or last_coin != coin:
        rake_change = initial_bank * rake * -2
        initial_bank = initial_bank + rake_change
    
    last_side = side
    last_coin = coin

    
    
    
    
initial_bank
# Out:
# 110.1023771543401

# %%
# A always rake

initial_bank = 100
rake = 0.00018


for i in range(len(predictsA)):
    if i ==0:
        continue

    predicts = predictsA
    p, side = predicts[i]
    if side ==0:
        rake_change = initial_bank * rake * -2
        initial_bank = initial_bank + rake_change
        continue



    change = initial_bank * p
    initial_bank = initial_bank + change
    
    rake_change = initial_bank * rake * -2
    initial_bank = initial_bank + rake_change

    
initial_bank
# Out:
# 88.25472731150657

# %%
# B always rake

initial_bank = 100
rake = 0.00018


for i in range(len(predictsB)):
    if i ==0:
        continue

    predicts = predictsB
    p, side = predicts[i]
    if side ==0:
        rake_change = initial_bank * rake * -2
        initial_bank = initial_bank + rake_change
        continue



    change = initial_bank * p
    initial_bank = initial_bank + change
    
    rake_change = initial_bank * rake * -2
    initial_bank = initial_bank + rake_change

    
initial_bank
# Out:
# 88.25472731150657

# %%
# C always rake

initial_bank = 100
rake = 0.00018


for i in range(len(predictsC)):
    if i ==0:
        continue

    predicts = predictsC
    p, side = predicts[i]
    if side ==0:
        rake_change = initial_bank * rake * -2
        initial_bank = initial_bank + rake_change
        continue



    change = initial_bank * p
    initial_bank = initial_bank + change
    
    rake_change = initial_bank * rake * -2
    initial_bank = initial_bank + rake_change

    
initial_bank
# Out:
# 88.25472731150657
