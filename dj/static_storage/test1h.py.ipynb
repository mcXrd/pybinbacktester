# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
import numpy as np
import tqdm

# %%
path_to_df="v2_raw_28apr_28may_2021_eth_raw.hdf"
path_to_df_eth="v2_lagging_B28apr_28may_2021_eth.hdf"
path_to_df_ada="v2_lagging_B28apr_28may_2021_ada.hdf"

Apath_to_df_eth="v2_lagging_A22apr_22may_2021_eth.hdf"
Apath_to_df_ada="v2_lagging_A22apr_22may_2021_ada.hdf"

Bpath_to_df_eth="v2_lagging_B22apr_22may_2021_eth.hdf"
Bpath_to_df_ada="v2_lagging_B22apr_22may_2021_ada.hdf"

df = pd.read_hdf(path_to_df_ada)
df
# Out:
#                                   trade_in_3h_usdtfutures_ADAUSDT_close_price  \
# 2021-04-28 04:30:59.999000+00:00                                    -0.024310
# 2021-04-28 04:31:59.999000+00:00                                    -0.024254
# 2021-04-28 04:32:59.999000+00:00                                    -0.023677
# 2021-04-28 04:33:59.999000+00:00                                    -0.025454
# 2021-04-28 04:34:59.999000+00:00                                    -0.023670
# ...                                                                       ...
# 2021-05-28 20:38:59.999000+00:00                                    -0.015252
# 2021-05-28 20:39:59.999000+00:00                                    -0.012764
# 2021-05-28 20:40:59.999000+00:00                                    -0.011341
# 2021-05-28 20:41:59.999000+00:00                                    -0.015236
# 2021-05-28 20:42:59.999000+00:00                                    -0.011498
#
# ...

# %%
df.columns
df = df.drop(columns=df.columns)
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
a = df.iloc[0]
a
# Out:
# trade_in_3h_usdtfutures_ADAUSDT_close_price           -0.024310
# trade_in_2h_usdtfutures_ADAUSDT_close_price           -0.041629
# trade_in_1h_usdtfutures_ADAUSDT_close_price           -0.013785
# usdtfutures_ADAUSDT_close_price                       -0.002802
# usdtfutures_ADAUSDT_volume                             0.148918
# usdtfutures_ADAUSDT_number_of_trades                  -0.038462
# SMA(usdtfutures_ADAUSDT_close_price_5)                 0.000062
# SMA(usdtfutures_ADAUSDT_volume_5)                      0.167022
# SMA(usdtfutures_ADAUSDT_number_of_trades_5)            0.091397
# SMA(usdtfutures_ADAUSDT_close_price_30)                0.000193
# shift1_SMA(usdtfutures_ADAUSDT_close_price_30)        -0.000244
# SMA(usdtfutures_ADAUSDT_volume_30)                     0.113760
# shift1_SMA(usdtfutures_ADAUSDT_volume_30)              0.335982
# SMA(usdtfutures_ADAUSDT_number_of_trades_30)           0.010926
# shift1_SMA(usdtfutures_ADAUSDT_number_of_trades_30)    0.190058
# ...

# %%
b = df.iloc[60]
b
# Out:
# trade_in_3h_usdtfutures_ADAUSDT_close_price           -0.006132
# trade_in_2h_usdtfutures_ADAUSDT_close_price           -0.010672
# trade_in_1h_usdtfutures_ADAUSDT_close_price           -0.028233
# usdtfutures_ADAUSDT_close_price                       -0.003141
# usdtfutures_ADAUSDT_volume                             1.260877
# usdtfutures_ADAUSDT_number_of_trades                   1.612813
# SMA(usdtfutures_ADAUSDT_close_price_5)                -0.000513
# SMA(usdtfutures_ADAUSDT_volume_5)                      0.236252
# SMA(usdtfutures_ADAUSDT_number_of_trades_5)            0.226058
# SMA(usdtfutures_ADAUSDT_close_price_30)               -0.000304
# shift1_SMA(usdtfutures_ADAUSDT_close_price_30)        -0.000155
# SMA(usdtfutures_ADAUSDT_volume_30)                     0.230124
# shift1_SMA(usdtfutures_ADAUSDT_volume_30)              0.245752
# SMA(usdtfutures_ADAUSDT_number_of_trades_30)           0.112820
# shift1_SMA(usdtfutures_ADAUSDT_number_of_trades_30)    0.147161
# ...

# %%
#(b["usdtfutures_ETHUSDT_close_price"]/a["usdtfutures_ETHUSDT_close_price"]) -1

# %%
#b["usdtfutures_ETHUSDT_close_price"]

# %%
#a["usdtfutures_ETHUSDT_close_price"]

# %%
#a["trade_in_1h_usdtfutures_ETHUSDT_close_price"]

# %%
def check_x_for_leak(X):
    for column in X.columns:
        assert "trade_in_" not in column

# %%
def create_model(path_to_hdf, index, train_size, test_size, coin):
    df_orig = pd.read_hdf(path_to_hdf)
    df_orig = df_orig.fillna(0)
    del df_orig["trade_in_3h_usdtfutures_{}USDT_close_price".format(coin)]
    del df_orig["trade_in_2h_usdtfutures_{}USDT_close_price".format(coin)]
    start = index - (train_size+test_size)
    end = index
    df_orig = df_orig[start:end]

    df = df_orig.copy()
    Y = df["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)]

    Y_MEAN = np.mean(np.abs(Y))
    Y_MEAN = Y_MEAN * (1/4)

    Y[df["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)] > Y_MEAN] = 20
    Y[df["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)] < -Y_MEAN] = 10
    Y[df["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)] < 9] = 1

    X = df_orig.loc[:, "usdtfutures_{}USDT_close_price".format(coin) :]
    check_x_for_leak(X)

    test_size = test_size / (test_size+train_size)
    test_size = test_size or 0.01
    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=test_size, random_state=6, shuffle=False
    )
    hours_in_test = len(Y_test)

    model = XGBClassifier(
        objective="multi:softprob",
        num_class=3,
        booster="gbtree",
        gamma=0.1,
        sampling_method=["uniform", "gradient_based"][0],
        num_parallel_tree=1,
        reg_alpha=1,
        reg_lambda=0,
        eta=0.3,
    )
    model.fit(X_train, Y_train)
    return model

# %%
def predict_row(path_to_hdf, index, model, coin):
    df_orig = pd.read_hdf(path_to_hdf)
    df_orig = df_orig.fillna(0)
    del df_orig["trade_in_3h_usdtfutures_{}USDT_close_price".format(coin)]
    del df_orig["trade_in_2h_usdtfutures_{}USDT_close_price".format(coin)]
    df_orig = df_orig.iloc[index:index+1]
    
    X = df_orig.loc[:,"usdtfutures_{}USDT_close_price".format(coin) :]
    check_x_for_leak(X)
    y_pred = model.predict(X)[0]
    Y_TEST_REAL = df_orig["trade_in_1h_usdtfutures_{}USDT_close_price".format(coin)][0]
    
    profit = -1
    
    side = -1
    if y_pred == 20:
        side = 1
    if y_pred == 1:
        return 0

    if side * Y_TEST_REAL > 0:
        profit = 1
    
    return abs(Y_TEST_REAL) * profit

# %%
predicts_adaA = []
predicts_ethA = []
predicts_adaB = []
predicts_ethB = []
model_c = 11
model=None
for i in tqdm.tqdm(range(60*24*6, 60*24*10, 60)):
#for i in tqdm.tqdm(range(41000, 44289, 60)):
    model_c -= 1
    if model_c ==0:
        model_c = 10
    
    if model_c ==10:
        pass
    model_adaA = create_model(Apath_to_df_ada, i, 60*36*1, 60, "ADA")
    model_ethA = create_model(Apath_to_df_eth, i, 60*36*1, 60, "ETH")
    model_adaB = create_model(Bpath_to_df_ada, i, 60*36*1, 60, "ADA")
    model_ethB = create_model(Bpath_to_df_eth, i, 60*36*1, 60, "ETH")
    predict_adaA = predict_row(Apath_to_df_ada, i, model_adaA, "ADA")
    predict_ethA = predict_row(Apath_to_df_eth, i, model_ethA, "ETH")
    predict_adaB = predict_row(Bpath_to_df_ada, i, model_adaB, "ADA")
    predict_ethB = predict_row(Bpath_to_df_eth, i, model_ethB, "ETH")
    #predict_eth = predict_ada
    #predict_ada = predict_eth
    predicts_adaA.append(predict_adaA)
    predicts_ethA.append(predict_ethA)
    predicts_adaB.append(predict_adaB)
    predicts_ethB.append(predict_ethB)
# Out:
#   0%|          | 0/96 [00:00<?, ?it/s]/home/vaclavmatejka/anaconda3/envs/pybinbacktester/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:02:03] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
initial_bank = 100
rake = 0.00018

for i in range(len(predicts_adaA)):
    if i ==0:
        continue
    
    predicts_lists = [predicts_adaA,predicts_ethA,predicts_adaB,predicts_ethB]
    results = [predicts_adaA[i-1],predicts_ethA[i-1],predicts_adaB[i-1] < predicts_ethB[i-1]]
    max_i = np.argmax(results)
    p = predicts_lists[max_i][i]

    change = initial_bank * p
    initial_bank = initial_bank + change
    
    rake_change = initial_bank * rake * -2
    initial_bank = initial_bank + rake_change
    
    
    
    
initial_bank
# Out:
# 98.70282311650425
